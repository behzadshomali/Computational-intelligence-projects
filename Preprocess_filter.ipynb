# %%
# !pip3 install gensim
# !pip3 install pyspellchecker

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
import gensim.downloader
from spellchecker import SpellChecker
import re
import pickle

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df = pd.read_csv('/content/drive/MyDrive/NLP_proj/NLP_train.csv')

# %%
train_df.shape
# Out:
# (8695, 3)

# %%
train_df.head()
# Out:
#        Id                                            Comment      Topic
# 0   0x840  A few things. You might have negative- frequen...    Biology
# 1   0xbf0  Is it so hard to believe that there exist part...    Physics
# 2  0x1dfc                                     There are bees    Biology
# 3   0xc7e  I'm a medication technician. And that's alot o...    Biology
# 4   0xbba                     Cesium is such a pretty metal.  Chemistry

# %% [markdown]
# ## Preprocess

# %%
# List of different exisitng pre0trained word2vec models 
list(gensim.downloader.info()['models'].keys())
# Out:
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']

# %%
word2vec_model = gensim.downloader.load('word2vec-google-news-300')

# %%
def preprocess_sentecnce(sentence, tokenizer, lemmatizer, stop_words):
    sentence = sentence.replace(r'\n', ' ')
    sentence = re.sub(r'\d+', '', sentence) # remove numbers
    tokens = tokenizer.tokenize(sentence) # split a sentence into tokens
    filtered_tokens = []
    for token in tokens:
        if token.lower() not in stop_words:
            lemmatized_token = lemmatizer.lemmatize(token)
            filtered_tokens.append(lemmatized_token.lower())
            
    return '#'.join(np.unique(filtered_tokens)) # form a string from obtained tokens

# %%
stop_words = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r'([a-zA-Z]+|[0-9]+)')

# %%
train_df['Unique_tokens'] = train_df['Comment'].apply(
    lambda row: preprocess_sentecnce(
        row, 
        tokenizer, 
        lemmatizer, 
        stop_words
        )
    )

# %%
train_df['Unique_tokens'].iloc[537]
# Out:
# 'also#communication#en#fiber#free#http#laser#optical#org#part#point#require#setup#space#wiki#wikipedia'

# %%
train_df.head()
# Out:
#        Id                                            Comment      Topic  \
# 0   0x840  A few things. You might have negative- frequen...    Biology
# 1   0xbf0  Is it so hard to believe that there exist part...    Physics
# 2  0x1dfc                                     There are bees    Biology
# 3   0xc7e  I'm a medication technician. And that's alot o...    Biology
# 4   0xbba                     Cesium is such a pretty metal.  Chemistry
#
#                                        Unique_tokens
# 0  advantage#allele#alter#alternating#animal#anot...
# 1  anything#believe#detect#exist#far#find#hard#hu...
# 2                                                bee
# 3  alot#body#care#definitely#die#drug#fine#good#i...
# 4                                cesium#metal#pretty

# %%
len(np.unique('#'.join(train_df['Unique_tokens'].tolist()).split('#')))
# Out:
# 15107

# %%
len(np.unique(' '.join(train_df['Comment'].tolist()).split()))
# Out:
# 34079

# %%
print(f'The word2vec model conatins vector of {len(word2vec_model.vocab):,} words!')
# Out:
# The word2vec model conatins vector of 3,000,000 words!

# %%
all_unique_words_list = np.unique('#'.join(train_df['Unique_tokens'].tolist()).split('#'))

# %%
cnt = 0
words = []
words_vectors = []
spell_checker = SpellChecker()

for indx, word in enumerate(all_unique_words_list):
    if indx % 2000 == 0:
        print(f'Stored {indx}/{len(all_unique_words_list)} words already!')
    
    try:
        if word not in word2vec_model.vocab:
            word = spell_checker.correction(word)

        words_vectors.append(word2vec_model[word])
        words.append(word)
    except Exception as e:
        print(word)
        cnt += 1
print(cnt)
# Out:
# Stored 0/15107 words already!
# aaaaaaaam
# armand
# bronson
# abloblololo
# abruptchaos
# abyssinian
# and
# acetylpyridine
# acetylsalicylic
# acetylsalicys
# acsnoqnsqm
# alaric
# agaricus
# aharonov
# ahukewimfpsvozahxmttabhr
# akron
# akshually
# alcoholicsanonymous
# alcohol's
# aldrich
# albania
# alhambra
# alizarine
# aluminium
# amanitamuscaria
# amaurobiidae
# amaurobius
# aminoethyl
# amita
# anakin
# analyse
# analysed
# analysing
# andrussow
# anesthesysed
# anfo
# anl
# anomalocaris
# antisolvent
# antivaxer
# antivaxxers
# antumbra
# aome
# aovvawvtjzwxrnzfodxbunov
# arabians
# arachnoboards
# archaeoglobus
# archimagirus
# archimedes
# argiope
# arius
# ariolimax
# arxiv
# armillaria
# arnold's
# arrestfauci
# arse
# arstechnica
# artantica
# articlelanding
# arxiv
# askdocs
# askentomologists
# askphysics
# askreddit
# astrochem
# atc
# audubon
# aurantia
# austentising
# autocannibalism
# autohotkey
# automail
# automatonrobotics
# avagadro
# ayvbkafwg
# azelaic
# azidothymidine
# aztec
# backreaction
# barnard
# basidiomycota
# beardocide
# beautihorrifying
# beber
# bechbwsuuq
# beeman
# beermeisters
# beest
# behaviour
# benzoic
# berlinsky
# bernoulli
# besttutor
# bethink
# bfupaaekcq
# bigbrainreddit
# bigelow
# biochemcoyrse
# bioinorganic
# biologyonline
# biomedcentral
# blueshift
# bohr
# boltzmann
# borexino
# boric
# bottiquette
# bqhbq
# braindamageinaction
# brasilia
# brasileiras
# brjkmkw
# braham
# brokovich
# brom
# bromethalene
# brownian
# brzrzrzrzzzz
# btmoyrllym
# bugguide
# bullcum
# bunsen
# butyric
# buut
# cabbagepatch
# naesin
# caesium
# cairnsnews
# californianewstimes
# caltech
# camachem
# cancelled
# cancercenter
# capitalisation
# capitalised
# capote
# caprylate
# carbfix
# carbonitrile
# cardassians
# carpometacarpal
# casomorphins
# cativeiro
# Stored 2000/15107 words already!
# cbcfwdr
# cbdywcl
# cbhsfdzp
# chex
# cbjsgkp
# cbkfndy
# cbsjyfja
# cbuurec
# ccbaeeecccee
# cccdb
# centimetre
# centre
# centred
# cerevisiiphilus
# certo
# chalmers
# chama
# tchaikovsky
# chemdraw
# chemdrawdirect
# chemguide
# chemhelp
# chemistryhelp
# chemistrymemes
# chemistryworld
# chemlabs
# chemonoia
# chemotropism
# chemphobia
# chemrxiv
# chemsketch
# chemtubed
# chernobyl
# chilimath
# chjvgki
# chlamydomonas
# chlorobutanol
# christo
# chung's
# chuuuuuunky
# ciro
# cjkcqjwinslbhcparisakns
# clem
# clickbait
# climeworks
# candarian
# colaboradores
# colibactin
# colour
# coloured
# colourful
# colouring
# colourless
# commensalism
# comprendo
# confidentlyincorrect
# contamenium
# contamfam
# cooperativity
# copypasta
# kotow
# couid
# cozedzloo
# crbxvpjm
# creationevolution
# cristatus
# croslinked
# crystalverse
# ctenophore
# ctfuuuu
# cubensis
# cucurbita
# cukclbfkw
# cumberbatch
# customsensorsolutions
# cyberninjas
# cyclohexylethyl
# cyclooctadiene
# cyclopentadiene
# dack
# dadjokeseventhoughimnotadad
# danstanley
# darwinawards
# dbeoivad
# duscan
# dbskmhxy
# dcbcacbfddbedddadc
# decahydroquinolin
# decarboxylate
# decarboxylation
# decepticon
# defence
# degrasse
# dessa
# dehaene
# deliquiscent
# deliriant
# demonstrandum
# demony
# denatonium
# denaturalizing
# dependant
# dephosphorolates
# dephosphorylated
# dephosporation
# deprotonate
# deprotonates
# dermestid
# descartes
# dessa
# desulfoviridin
# determinativkomposition
# deu
# deuteron
# deuteron
# deberia
# deviantart
# devons
# diaminohexane
# diastereotopic
# diazabicyclo
# diazepines
# dibromobenzene
# dibuthylsulphide
# dichroism
# didnt
# diethylzinc
# differentiatiation
# dimethylethanamine
# dimethylsulphide
# dinonooo
# diptera
# dirai
# discgolf
# discovermagazine
# dithiane
# divisibilty
# and
# dobsonfly
# doesnt
# Stored 4000/15107 words already!
# domyhomeworkforme
# don'tneed
# dontputyourdickinthat
# dooba
# doritos
# downscatter
# downvote
# downvoted
# downvotes
# dresden
# drury
# duranium
# duckduckgo
# dumas
# dumbshits
# dupont
# dysparxia
# dystanttyger
# eafajtulslzh
# easycalculation
# eddddedecebeacbcca
# edna
# eenzbbmm
# efeedbcdfc
# elsa
# efwxrsdug
# ehat
# ehy
# eigensolvers
# eigenstates
# einsteinian
# einsteinian
# einsteins
# einstenium
# electromegativities
# electronegative
# electronegativity
# electrophiles
# electropolished
# elmer
# elon
# embiggening
# emownuoakdr
# emphasise
# emptyolgists
# endophallus
# energyeducation
# englanders
# entienne
# enzbsokgg
# enzimatically
# eppendorf
# epsom
# epstein
# equalandoppositereaction
# erythropoesis
# escher
# escherichia
# espero
# estudiar
# ethanoate
# euclidean
# eurekaselect
# everclear
# everettwheeler
# evermica
# exepection
# experiencence
# exponentiation
# expotum
# extravasated
# eyxqfyvw
# faraday
# farinalis
# favour
# favourable
# favourite
# fazer
# fccacaa
# fdaafcbddbff
# fermilab
# fertiliser
# fenian
# feynmanlectures
# feynmann
# fiire
# fingerlakesstem
# flavour
# flavoured
# flemming
# flerovium
# fluorosilicic
# flymushroom
# folderview
# fomitopsis
# foodscience
# forbiddenfood
# forbiddenfoods
# forbiddenicecream
# forbiddensnacks
# forjesus
# fpfjspdbzg
# frujwf
# fty
# fuge
# fulgidus
# furanoses
# fusobacterium
# gabaergics
# gabaxodol
# galadriel
# galileans
# galileo
# galinstan
# galvanised
# gardentherapy
# gaslighting
# gassensordemo
# gbzvkqinim
# gclsrc
# gdy
# gellhlumcxhngi
# getback
# geomyidae
# georgi
# germanic
# getvideo
# gewfxwrpza
# ghirardelli
# giancoli
# giberellin
# gingerbeervitusbacterium
# glassdoor
# glendale
# glowscript
# glucuronic
# glycerophospholipids
# goddard
# gof
# goldstein
# golgi
# goodenough
# goomedicines
# graphitization
# grey
# griffith
# grignard
# growingsmallfarms
# gudiwsprgj
# Stored 6000/15107 words already!
# hacklemesh
# haemoglobin
# haibach
# halbschatten
# haloform
# hamiltonian
# hamiltons
# handfeeding
# hapsburg
# harbour
# hayworth
# hayrick
# hazeldenbettyford
# hdfqyzw
# heisenberg
# heisenberg
# helmholtz
# helminthicplatypus
# henri
# hermetcism
# heteroaromatic
# heteroatom
# hexacyanidoferrate
# hexaflouride
# hexaflurophospate
# hexalfuoride
# hexapoda
# hgzfx
# hgztvz
# higgs
# highefficiency
# hitchcock
# hkhzjguta
# hnialyqn
# hogwarts
# howmany
# holp
# homeworkhelp
# hossenfelder
# hsahealth
# hubblesite
# humperdink
# huuurrrr
# huygens
# hybridness
# hydrohomies
# hydrotropism
# hydroxyformamidinium
# hypervalent
# hypochlorous
# iaaurirxdo
# ibotenic
# icechameleon
# icecharmelion
# icecore
# icjnknn
# iding
# iga
# i'm
# igualmente
# iiyamaqcpxrpdpkhsnykm
# imagevideo
# infelizmente
# inocybe
# intensivamente
# intercarpal
# intermodular
# interpunctella
# ionpymfe
# iossmf
# iqs
# iridyscenzia
# irene
# irishishum
# irishman
# isnt
# isoamyl
# isochoric
# isocyanides
# ithis
# itif
# i'd
# jajajaa
# jajajajajajaja
# jasonbidwell
# joby
# jhedberg
# jhsltley
# jkfnvorbslzmvsjazmfwqpja
# joinchat
# josephson
# jowomr
# jpclett
# jsessionid
# judgement
# juvonen
# jyqwgbaabag
# kablammo
# karyogamy
# kernschatten
# khanacademy
# kjeldahl
# klinger
# kostyantyn
# kratom
# kruger
# kuuurrrrvaaaa
# kyrie
# kzscrhk
# labelled
# labmanager
# lacroix
# lagrangian
# lamming
# laplanders
# lbzufzrqyvo
# learnt
# lengthscale
# lengthscales
# leptodactylus
# leptogenesis
# levine
# lgeaoxbza
# libretexts
# licence
# liduttkeq
# lightfoot
# lightseconds
# lile
# lipinksi
# lithobates
# litre
# litres
# livescience
# lkbqvxeq
# lllustrated
# lmdtjiawe
# lmfairlylocal
# lmfaooooooo
# lockheed
# loeb
# ooooooooh
# ooooooooh
# lorenz
# lothal
# lottttttt
# luca
# luigi
# pottinger
# lymphknots
# Stored 8000/15107 words already!
# lysol
# mallinckrodt
# mansplaining
# marangoni
# marcescens
# marescens
# mariokart
# massenkommunikationsdienstleistungsunternehmen
# maximilian
# maximise
# mayans
# mcconville
# mcguever
# mckenna
# mcnuggets
# mdma
# megakarocyte
# megasphaera
# megataxonomies
# melscience
# memorise
# memorising
# menagesha
# mendel
# mentos
# mercaptoethanol
# meridionalis
# mesoamerican
# mesylating
# metasurfaces
# meterstick
# methususerus
# methylbenzyl
# methylbutane
# methyltriethylammonium
# methyltrimethoxysilane
# metre
# mev
# michio
# microbialfoods
# midichlorians
# midsouth
# miekakure
# mietfwk
# millimetre
# millie
# generalisation
# mineralised
# miniboone
# mininuclear
# minkowski
# minos
# misestimate
# mmmmmmmmagic
# mno
# modelled
# modelling
# malone
# monoatomic
# monobasic
# mononitride
# monosubstituted
# monotypic
# mould
# mrbigler
# mrna
# muscimol
# mwxkelrgok
# mxmzhyzefy
# mycoxaflopin
# mydixahardin
# myxomycota
# nakplnnackehceedgkgkokbgbmfghain
# nanolipid
# naturwissenschaften
# nautiloids
# nbbjniwtk
# ncis
# nde
# needeth
# neighbour
# nepetalactone
# neutralisation
# neutralise
# nextfuckinglevel
# niels
# nikola
# nileblue
# nitroglyrecirn
# nnggmacv
# nocardia
# noneuclidean
# nonino
# noodlenose
# norbornadiene
# oreste
# nosey
# nothingburgers
# nothowgirlswork
# nought
# nucleatum
# nucleophiles
# nucliede
# obrigado
# ocd
# oceanservice
# odour
# odours
# offence
# ohhhhhh
# ohhhhhhhh
# ohhhhhhhhhhhhhh
# oktoberfest
# olga
# onekindplanet
# onestagetospace
# onlinelibrary
# oooohhhh
# openculture
# openscholarship
# openscience
# opisthokonts
# oppa
# opsonised
# optimise
# of
# organells
# organisation
# organiser
# organising
# organometalic
# orgchem
# oriol
# orthopaedic
# oswald
# oxazole
# pagodinho
# panpsychism
# pantropical
# paracelsus
# parada
# parametrised
# paywalled
# pcwbyx
# pectinatus
# pediococci
# pediococcus
# peiajokffs
# pentahydrate
# pepto
# perchloroethylene
# perfluorooctanesulfonic
# perflurooctanoic
# perfusing
# pergunta
# periquito
# perkinelmer
# permian
# poca
# foa
# phalliiodes
# phalliodies
# phalloide
# phaloupian
# pharmocopeia
# phenomenologist
# phenylethyl
# phidippus
# philosophyofscience
# phoneutria
# Stored 10000/15107 words already!
# physicsclassroom
# physicsmemes
# picard
# picasso
# pivnenko
# placentophagia
# placentophagy
# plaguefactsheet
# planck
# plasmogamy
# plkldmf
# ploughed
# pnictogen
# pode
# poissonian
# polarisation
# polyatomic
# polydrusus
# polylactic
# pornhub
# poseidon
# potsdam
# pritchett
# precisaria
# prends
# preposterousuniverse
# pressurised
# procesionaria
# processionaires
# profmattstrassler
# programme
# proteinogenic
# proteus
# protonate
# protonates
# prussian
# pscilocin
# psychonaut
# psychonauts
# psychopathictendencies
# punxsutawney
# pyranoses
# pyrazinedicarboxylic
# pyrolizing
# pysilocybe
# qbctf
# qbknp
# ocd
# qe
# qevwb
# qfxyqr
# qgevb
# qgkgek
# qhkrz
# qibkco
# qjnzsj
# quantamagazine
# quantumphysicsmadesimple
# quimica
# quimico
# radiophobia
# randos
# rateofchange
# abcs
# readingrockets
# realisation
# realise
# realised
# realising
# recognise
# recognised
# recognising
# recommand
# recrystalization
# recrystalize
# redditautocrosspostbot
# redditrequest
# redditsave
# reduviidae
# renormalizable
# researchgate
# resourcekey
# retrocausality
# retrosynthesis
# reu
# rfznsag
# rhombohedral
# hisjob
# rlly
# umbr
# rna
# rojas
# romanians
# rotavap
# rotovap
# roundbottom
# rtkweb
# rumour
# sabine
# sabine
# sabre
# saddestofboys
# sagittarius
# saludossssssss
# saponifed
# savedyouaclick
# savevideo
# sazyqtvbaggeai
# sceptic
# schrodinger
# schroeder
# sciencedirect
# scienceniumreddit
# sciencenotes
# scientificamerican
# scifinder
# sciuridae
# scorbicula
# scotia
# scully
# sdtahiwg
# seaborgium
# segal
# semanticscholar
# semiclassical
# semiclassically
# semiparticles
# senegal
# Stored 12000/15107 words already!
# sexyhusband
# shakespeareinsult
# shamalayamadingdong
# sheldon
# sheldoncomics
# shhhhhhh
# shitposts
# shouldst
# shutterstock
# shyamalan
# siberia
# sigmaaldrich
# sigourney
# skynet
# smallmourh
# smarandache
# arxiv
# sneakysasquatch
# sneed
# socialsciences
# sofisticated
# solvingtheuniverse
# sombras
# somnifrerum
# sonething
# soybeanology
# spacetimetravel
# spasmatism
# specialisation
# specialising
# speciality
# spelt
# spiderzrule
# spiegelman
# sporactivas
# spunkydred
# srednicki
# sscmedicines
# ssqsnpwya
# stabilimentum
# stackexchange
# stahhhhhp
# starman
# statoliths
# seeit
# steemswede
# setrakian
# stereoisomer
# stereoisomers
# stereospecific
# strawful
# strempeliopine
# stroopwafels
# styropyro
# suba
# subphylum
# subreddit
# subreddits
# suddenlycaralho
# sufferworthy
# suicidepreventionlifeline
# sulphur
# sulphuric
# summarise
# summarised
# supertees
# supongo
# surtees
# susceptometer
# swole
# swortsinaggereous
# symbolises
# synchondroses
# syndesmoses
# syngamy
# syntetisis
# synthesised
# tachyons
# takjukpq
# tandfonline
# tantalising
# tatp
# tbat
# tbat
# tcgabiolinks
# tchwiqdks
# tdtmvjournal
# teenheaven
# tegmental
# tektronix
# terephthalic
# terrance
# terrence
# tesselate
# tessellate
# tesseract
# teste
# tetraborate
# tetrahydroborate
# tetrahydrofurane
# tetrahydropyrimidine
# tetramethoxysilane
# tev
# thamutepoea
# thatall
# thatd
# thaumetopoea
# theconversation
# theforestcommunity
# therans
# therapize
# thermofisher
# thermoproperties
# thermoregulate
# theu
# thiazolines
# thioanisol
# thiophenol
# thirdmost
# thugtail
# tierzoo
# tillamook
# tiredlit
# tompkins
# torricelli
# tosylating
# totalled
# transcriptase
# transesterify
# transmissionselektronenmikroskopie
# trapinch
# trayendo
# travelled
# traveller
# travelling
# treponema
# triatomine
# triethylamine
# trimethylsilylacetylene
# triphenylphosphinegold
# ttwo
# tugwakebhts
# tumour
# tutorialsexercises
# tyiocfyzms
# uahauahuahau
# Stored 14000/15107 words already!
# ucgkmwkuyzfenzxvbapw
# utau
# ufmalbu
# ukxqtvqcpsg
# ultrafiltering
# ultrarapid
# umzdnyriato
# universidad
# unliving
# unorginality
# ununoctium
# upl
# upyqarvg
# urushriol
# usajobs
# uselessnobody
# uselessnoone
# utilise
# vaccinefreedom
# vape
# vapour
# baxters
# vclbx
# veritasium
# viewcontent
# vigreaux
# viltrumite
# viltrumites
# vinylacetylene
# viraloading
# virgmeister
# viruscorona
# visualisation
# visualise
# vkvidrhoeknttixbltmihkredsulgqlhrqbhxqaapoeealw
# vmeblhtvxoc
# vodkabeer
# volumefinal
# wasnt
# wavefunctions
# webtoon
# weltensammler
# welwitschia
# wemakescholars
# westeros
# wfscjobs
# whatdo
# whatthis
# whatisthisbug
# whatisthisthing
# whatsthisbug
# whereare
# whisky
# wholesomememes
# wharton
# wikilink
# wikimobilelinkbot
# wikisummarizer
# wikisummarizerbot
# wilczek
# windex
# wolframalpha
# wonderopolis
# wonka
# woodward
# woolworth
# workoutroutines
# wowproductimages
# wrwgijbuyvc
# wtygtiochxe
# wuwdmzkygm
# wvpcsdq
# wxbgfkyc
# cantate
# xianyang
# xwdkpfbomfdkdgyyunkwvhm
# xiu
# ybxlmphcmc
# ycsgolc
# yellowstone
# yemlncrea
# yesh
# youuu
# ytellxk
# ytxxg
# yzdhegspks
# zacky
# zapata
# zdtcaftkz
# hellinger
# zeiss
# zeng
# azeroth
# zika
# zlosnik
# zoidberg
# ztsiclxmjw
# zubairy
# zurich
# zwitterion
# zyklon
# 1128

# %%
with open('words.pkl', 'wb') as f:
    pickle.dump(words, f)

with open('words_vectors.pkl', 'wb') as f:
    pickle.dump(words_vectors, f)
